# %% [markdown]
# # DEEP TRANSFER LEARNING
# Pemanfaatan Deep Transfer Learning Mode 1

# %%
#Import library yang dibutuhkan
from keras.applications.efficientnet_v2 import EfficientNetV2M
from keras.applications.mobilenet_v2 import MobileNetV2

#Deklarasikan model yang akan dipakai
model = EfficientNetV2M()
#model = MobileNetV2()

#Tampilkan layer-layer model VGG16
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m.h5
# 219332608/219330792 [==============================] - 3s 0us/step
# 219340800/219330792 [==============================] - 3s 0us/step
# Model: "efficientnetv2-m"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 480, 480, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 480, 480, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 240, 240, 24  648         ['rescaling[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 240, 240, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 240, 240, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 240, 240, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 240, 240, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 240, 240, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 240, 240, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 240, 240, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 240, 240, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 240, 240, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_add (Add)              (None, 240, 240, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]',
#                                                                   'block1a_add[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 240, 240, 24  5184        ['block1b_add[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 240, 240, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_project_activation (Ac  (None, 240, 240, 24  0          ['block1c_project_bn[0][0]']
#  tivation)                      )
#
#  block1c_add (Add)              (None, 240, 240, 24  0           ['block1c_project_activation[0][0
#                                 )                                ]',
#                                                                   'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 120, 120, 96  20736       ['block1c_add[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 120, 120, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 120, 120, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_project_conv (Conv2D)  (None, 120, 120, 48  4608        ['block2a_expand_activation[0][0]
#                                 )                                ']
#
#  block2a_project_bn (BatchNorma  (None, 120, 120, 48  192        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 120, 120, 19  82944       ['block2a_project_bn[0][0]']
#                                 2)
#
#  block2b_expand_bn (BatchNormal  (None, 120, 120, 19  768        ['block2b_expand_conv[0][0]']
#  ization)                       2)
#
#  block2b_expand_activation (Act  (None, 120, 120, 19  0          ['block2b_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2b_project_conv (Conv2D)  (None, 120, 120, 48  9216        ['block2b_expand_activation[0][0]
#                                 )                                ']
#
#  block2b_project_bn (BatchNorma  (None, 120, 120, 48  192        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_add (Add)              (None, 120, 120, 48  0           ['block2b_project_bn[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 120, 120, 19  82944       ['block2b_add[0][0]']
#                                 2)
#
#  block2c_expand_bn (BatchNormal  (None, 120, 120, 19  768        ['block2c_expand_conv[0][0]']
#  ization)                       2)
#
#  block2c_expand_activation (Act  (None, 120, 120, 19  0          ['block2c_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2c_project_conv (Conv2D)  (None, 120, 120, 48  9216        ['block2c_expand_activation[0][0]
#                                 )                                ']
#
#  block2c_project_bn (BatchNorma  (None, 120, 120, 48  192        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_add (Add)              (None, 120, 120, 48  0           ['block2c_project_bn[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 120, 120, 19  82944       ['block2c_add[0][0]']
#                                 2)
#
#  block2d_expand_bn (BatchNormal  (None, 120, 120, 19  768        ['block2d_expand_conv[0][0]']
#  ization)                       2)
#
#  block2d_expand_activation (Act  (None, 120, 120, 19  0          ['block2d_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2d_project_conv (Conv2D)  (None, 120, 120, 48  9216        ['block2d_expand_activation[0][0]
#                                 )                                ']
#
#  block2d_project_bn (BatchNorma  (None, 120, 120, 48  192        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_add (Add)              (None, 120, 120, 48  0           ['block2d_project_bn[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 120, 120, 19  82944       ['block2d_add[0][0]']
#                                 2)
#
#  block2e_expand_bn (BatchNormal  (None, 120, 120, 19  768        ['block2e_expand_conv[0][0]']
#  ization)                       2)
#
#  block2e_expand_activation (Act  (None, 120, 120, 19  0          ['block2e_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2e_project_conv (Conv2D)  (None, 120, 120, 48  9216        ['block2e_expand_activation[0][0]
#                                 )                                ']
#
#  block2e_project_bn (BatchNorma  (None, 120, 120, 48  192        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_add (Add)              (None, 120, 120, 48  0           ['block2e_project_bn[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 60, 60, 192)  82944       ['block2e_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 60, 60, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 60, 60, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 60, 60, 80)   15360       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 60, 60, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 60, 60, 320)  230400      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 60, 60, 320)  1280       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 60, 60, 320)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 60, 60, 80)   25600       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 60, 60, 80)  320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_add (Add)              (None, 60, 60, 80)   0           ['block3b_project_bn[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 60, 60, 320)  230400      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 60, 60, 320)  1280       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 60, 60, 320)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 60, 60, 80)   25600       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 60, 60, 80)  320         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_add (Add)              (None, 60, 60, 80)   0           ['block3c_project_bn[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 60, 60, 320)  230400      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 60, 60, 320)  1280       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 60, 60, 320)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 60, 60, 80)   25600       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 60, 60, 80)  320         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_add (Add)              (None, 60, 60, 80)   0           ['block3d_project_bn[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 60, 60, 320)  230400      ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 60, 60, 320)  1280       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 60, 60, 320)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_project_conv (Conv2D)  (None, 60, 60, 80)   25600       ['block3e_expand_activation[0][0]
#                                                                  ']
#
#  block3e_project_bn (BatchNorma  (None, 60, 60, 80)  320         ['block3e_project_conv[0][0]']
#  lization)
#
#  block3e_add (Add)              (None, 60, 60, 80)   0           ['block3e_project_bn[0][0]',
#                                                                   'block3d_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 60, 60, 320)  25600       ['block3e_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 60, 60, 320)  1280       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 60, 60, 320)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 30, 30, 320)  2880       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 30, 30, 320)  1280       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 30, 30, 320)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 320)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 320)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 20)     6420        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 320)    6720        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 30, 30, 320)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 30, 30, 160)  51200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 30, 30, 160)  640        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 30, 30, 640)  102400      ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 30, 30, 640)  2560       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 30, 30, 640)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 30, 30, 640)  5760       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 30, 30, 640)  2560       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 30, 30, 640)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 640)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 30, 30, 640)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 30, 30, 160)  102400      ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 30, 30, 160)  640        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_add (Add)              (None, 30, 30, 160)  0           ['block4b_project_bn[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 30, 30, 640)  102400      ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 30, 30, 640)  2560       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 30, 30, 640)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 30, 30, 640)  5760       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 30, 30, 640)  2560       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 30, 30, 640)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 640)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 30, 30, 640)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 30, 30, 160)  102400      ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 30, 30, 160)  640        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_add (Add)              (None, 30, 30, 160)  0           ['block4c_project_bn[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 30, 30, 640)  102400      ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 30, 30, 640)  2560       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 30, 30, 640)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 30, 30, 640)  5760       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 30, 30, 640)  2560       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 30, 30, 640)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 640)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 30, 30, 640)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 30, 30, 160)  102400      ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 30, 30, 160)  640        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_add (Add)              (None, 30, 30, 160)  0           ['block4d_project_bn[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 30, 30, 640)  102400      ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 30, 30, 640)  2560       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 30, 30, 640)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 30, 30, 640)  5760       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 30, 30, 640)  2560       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 30, 30, 640)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 640)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 30, 30, 640)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 30, 30, 160)  102400      ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 30, 30, 160)  640        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_add (Add)              (None, 30, 30, 160)  0           ['block4e_project_bn[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 30, 30, 640)  102400      ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 30, 30, 640)  2560       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 30, 30, 640)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 30, 30, 640)  5760       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 30, 30, 640)  2560       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 30, 30, 640)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 640)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 30, 30, 640)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 30, 30, 160)  102400      ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 30, 30, 160)  640        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_add (Add)              (None, 30, 30, 160)  0           ['block4f_project_bn[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block4g_expand_conv (Conv2D)   (None, 30, 30, 640)  102400      ['block4f_add[0][0]']
#
#  block4g_expand_bn (BatchNormal  (None, 30, 30, 640)  2560       ['block4g_expand_conv[0][0]']
#  ization)
#
#  block4g_expand_activation (Act  (None, 30, 30, 640)  0          ['block4g_expand_bn[0][0]']
#  ivation)
#
#  block4g_dwconv2 (DepthwiseConv  (None, 30, 30, 640)  5760       ['block4g_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4g_bn (BatchNormalization  (None, 30, 30, 640)  2560       ['block4g_dwconv2[0][0]']
#  )
#
#  block4g_activation (Activation  (None, 30, 30, 640)  0          ['block4g_bn[0][0]']
#  )
#
#  block4g_se_squeeze (GlobalAver  (None, 640)         0           ['block4g_activation[0][0]']
#  agePooling2D)
#
#  block4g_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4g_se_squeeze[0][0]']
#
#  block4g_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4g_se_reshape[0][0]']
#
#  block4g_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4g_se_reduce[0][0]']
#
#  block4g_se_excite (Multiply)   (None, 30, 30, 640)  0           ['block4g_activation[0][0]',
#                                                                   'block4g_se_expand[0][0]']
#
#  block4g_project_conv (Conv2D)  (None, 30, 30, 160)  102400      ['block4g_se_excite[0][0]']
#
#  block4g_project_bn (BatchNorma  (None, 30, 30, 160)  640        ['block4g_project_conv[0][0]']
#  lization)
#
#  block4g_add (Add)              (None, 30, 30, 160)  0           ['block4g_project_bn[0][0]',
#                                                                   'block4f_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 30, 30, 960)  153600      ['block4g_add[0][0]']
# ...
#  2D)                            )                                ']
#
#  block7b_bn (BatchNormalization  (None, 15, 15, 3072  12288      ['block7b_dwconv2[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 15, 15, 3072  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 15, 15, 3072  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 15, 15, 512)  1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 15, 15, 512)  2048       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_add (Add)              (None, 15, 15, 512)  0           ['block7b_project_bn[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 15, 15, 3072  1572864     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 15, 15, 3072  12288      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 15, 15, 3072  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv2 (DepthwiseConv  (None, 15, 15, 3072  27648      ['block7c_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7c_bn (BatchNormalization  (None, 15, 15, 3072  12288      ['block7c_dwconv2[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 15, 15, 3072  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 15, 15, 3072  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 15, 15, 512)  1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 15, 15, 512)  2048       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_add (Add)              (None, 15, 15, 512)  0           ['block7c_project_bn[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 15, 15, 3072  1572864     ['block7c_add[0][0]']
#                                 )
#
#  block7d_expand_bn (BatchNormal  (None, 15, 15, 3072  12288      ['block7d_expand_conv[0][0]']
#  ization)                       )
#
#  block7d_expand_activation (Act  (None, 15, 15, 3072  0          ['block7d_expand_bn[0][0]']
#  ivation)                       )
#
#  block7d_dwconv2 (DepthwiseConv  (None, 15, 15, 3072  27648      ['block7d_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7d_bn (BatchNormalization  (None, 15, 15, 3072  12288      ['block7d_dwconv2[0][0]']
#  )                              )
#
#  block7d_activation (Activation  (None, 15, 15, 3072  0          ['block7d_bn[0][0]']
#  )                              )
#
#  block7d_se_squeeze (GlobalAver  (None, 3072)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 15, 15, 3072  0           ['block7d_activation[0][0]',
#                                 )                                 'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 15, 15, 512)  1572864     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 15, 15, 512)  2048       ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_add (Add)              (None, 15, 15, 512)  0           ['block7d_project_bn[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2D)   (None, 15, 15, 3072  1572864     ['block7d_add[0][0]']
#                                 )
#
#  block7e_expand_bn (BatchNormal  (None, 15, 15, 3072  12288      ['block7e_expand_conv[0][0]']
#  ization)                       )
#
#  block7e_expand_activation (Act  (None, 15, 15, 3072  0          ['block7e_expand_bn[0][0]']
#  ivation)                       )
#
#  block7e_dwconv2 (DepthwiseConv  (None, 15, 15, 3072  27648      ['block7e_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block7e_bn (BatchNormalization  (None, 15, 15, 3072  12288      ['block7e_dwconv2[0][0]']
#  )                              )
#
#  block7e_activation (Activation  (None, 15, 15, 3072  0          ['block7e_bn[0][0]']
#  )                              )
#
#  block7e_se_squeeze (GlobalAver  (None, 3072)        0           ['block7e_activation[0][0]']
#  agePooling2D)
#
#  block7e_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7e_se_squeeze[0][0]']
#
#  block7e_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multiply)   (None, 15, 15, 3072  0           ['block7e_activation[0][0]',
#                                 )                                 'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv2D)  (None, 15, 15, 512)  1572864     ['block7e_se_excite[0][0]']
#
#  block7e_project_bn (BatchNorma  (None, 15, 15, 512)  2048       ['block7e_project_conv[0][0]']
#  lization)
#
#  block7e_add (Add)              (None, 15, 15, 512)  0           ['block7e_project_bn[0][0]',
#                                                                   'block7d_add[0][0]']
#
#  top_conv (Conv2D)              (None, 15, 15, 1280  655360      ['block7e_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 15, 15, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 15, 15, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 1280)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         1281000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 54,431,388
# Trainable params: 54,139,356
# Non-trainable params: 292,032
# __________________________________________________________________________________________________

# %%
import requests
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image

urls=[]
urls.append("https://post.healthline.com/wp-content/uploads/2020/08/3180-Pug_green_grass-732x549-thumbnail-732x549.jpg")
urls.append("https://static.toiimg.com/thumb/msid-60132235,imgsize-169468,width-800,height-600,resizemode-75/60132235.jpg")
urls.append("https://img.webmd.com/dtmcms/live/webmd/consumer_assets/site_images/article_thumbnails/other/cat_relaxing_on_patio_other/1800x1200_cat_relaxing_on_patio_other.jpg")
urls.append("https://i.guim.co.uk/img/media/26392d05302e02f7bf4eb143bb84c8097d09144b/446_167_3683_2210/master/3683.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=49ed3252c0b2ffb49cf8b508892e452d")
urls.append("https://media.wired.com/photos/61afb905d184762c75e00411/master/pass/Gear-Jackbrabbit-Bike-Yellow-top.jpg")
urls.append("https://cdn.mos.cms.futurecdn.net/ZvueiLL2vdwoHWHjCRuQCW-1200-80.jpg")
urls.append("https://images.theconversation.com/files/239356/original/file-20181004-52660-1fosymz.jpg?ixlib=rb-1.1.0&rect=121%2C5%2C3214%2C2309&q=45&auto=format&w=926&fit=clip")
urls.append("https://www.thesun.co.uk/wp-content/uploads/2019/09/NINTCHDBPICT000492607142-e1567357146264.jpg")
urls.append("https://asset.kompas.com/crops/ncgvDkq11ovx_624dxbv483x_iY=/0x0:648x432/750x500/data/photo/2021/10/05/615c371c61b81.jpg")
urls.append("https://wallpaperaccess.com/full/3396763.jpg")
urls.append("https://www.thehappychickencoop.com/wp-content/uploads/2019/01/chicken-and-hen.jpg")
urls.append("https://m.media-amazon.com/images/I/81KoSSAwH2L._SL1500_.jpg")

imgs=[]
plt.figure(figsize=(15,6))
for u in range(0,len(urls)):
  r = requests.get(urls[u], stream=True) #Download
  img = np.array(Image.open(r.raw))  #Konversi ke NP Array
  plt.subplot(1,len(urls),u+1) #Menampilkan ke matplotlib
  plt.imshow(img) #Menampilkan ke matplotlib
  img = cv2.resize(img, (480,480)) #Resize sesuai input VGG 16
  imgs.append(img) #Kumpulkan semua image yang telah di preproses ke imgs
plt.show() #Menampilkan ke matplotlib
imgs = np.array(imgs) #Konversi ke Np Array 
print (imgs.shape) #Debuging (Apakah shape-nya benar?)
# Out:
# (12, 480, 480, 3)

# %% [markdown]
# VGG 16 memiliki target 1000 kelas
# https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a
#
# Kelas anjing: 151 (Chihuahua) - 268 (Mexican hairless)
#
# Kelas kucing: 281 (tabby cat) - 287 (lynx)

# %%
yh = model.predict(imgs)
for i in range(len(urls)):
  if(np.argmax(yh[i]) >= 151 and np.argmax(yh[i])<=268 ):
      print("Anjing")
  elif(np.argmax(yh[i]) >= 281 and np.argmax(yh[i])<=287 ) :
      print("Kucing")
  elif(np.argmax(yh[i]) >= 7 and np.argmax(yh[i])<=8 ) :
      print("Ayam")
  elif(np.argmax(yh[i]) >= 387 and np.argmax(yh[i]) <=388):
      print("Panda")
  elif(np.argmax(yh[i]) == 671):
      print("Sepeda") 
  elif(np.argmax(yh[i]) == 620):
      print("Laptop") 
  else:
      print("Lainya")
# Out:
# Anjing
# Anjing
# Kucing
# Kucing
# Sepeda
# Anjing
# Ayam
# Ayam
# Panda
# Panda
# Ayam
# Lainya

# %%
yh.shape
# Out:
# (11, 1000)

# %%
yh[0]
# Out:
# array([1.39890864e-04, 2.31678699e-04, 1.03241277e-04, 1.05209467e-04,
#        1.76557209e-04, 1.32104658e-04, 1.62393437e-04, 1.82636795e-04,
#        1.33624024e-04, 1.52178749e-04, 2.09849502e-04, 1.50503518e-04,
#        1.07806693e-04, 1.10263420e-04, 2.04462936e-04, 1.58962808e-04,
#        1.52789507e-04, 1.58260023e-04, 1.76463800e-04, 1.36126633e-04,
#        1.35360257e-04, 7.88630568e-05, 1.06973050e-04, 1.44120204e-04,
#        1.30970395e-04, 1.90327060e-04, 2.62907182e-04, 2.02983487e-04,
#        1.49881031e-04, 1.79037335e-04, 2.18405505e-04, 1.84512828e-04,
#        2.53501290e-04, 1.39287280e-04, 1.43194207e-04, 2.02156443e-04,
#        1.58506227e-04, 1.75024761e-04, 1.08565953e-04, 1.65562087e-04,
#        1.44412712e-04, 1.41349112e-04, 1.39732860e-04, 1.74562345e-04,
#        1.55233050e-04, 2.87866424e-04, 1.44761158e-04, 1.83970944e-04,
#        2.26357399e-04, 1.35610273e-04, 1.90184990e-04, 7.41762487e-05,
#        1.60005264e-04, 2.34037303e-04, 2.04374839e-04, 1.22979938e-04,
#        1.60546362e-04, 2.04202413e-04, 1.14531227e-04, 1.73540859e-04,
#        1.73793247e-04, 1.34490285e-04, 7.96390304e-05, 8.55619437e-05,
#        1.56447568e-04, 1.44593243e-04, 1.56317081e-04, 1.87081343e-04,
#        1.52650275e-04, 2.13350620e-04, 2.16968896e-04, 7.44150384e-05,
#        1.48204388e-04, 2.04709955e-04, 1.35717142e-04, 1.77673021e-04,
#        2.31602273e-04, 1.49987696e-04, 1.02166421e-04, 1.17742871e-04,
#        1.38841540e-04, 2.09696664e-04, 1.15240640e-04, 1.39602736e-04,
#        1.10305067e-04, 9.47178341e-05, 1.27254069e-04, 2.10052545e-04,
#        1.23976410e-04, 2.54169194e-04, 1.63183955e-04, 1.60732787e-04,
#        1.06891559e-04, 1.34231726e-04, 8.28214397e-05, 7.64449287e-05,
#        3.95787822e-04, 1.80093062e-04, 2.12815343e-04, 2.01179631e-04,
#        2.01504503e-04, 1.85371595e-04, 1.25792503e-04, 1.78951799e-04,
#        1.16451163e-04, 2.33369137e-04, 1.65544247e-04, 1.24564103e-04,
#        1.52961700e-04, 1.33458831e-04, 1.55612201e-04, 1.39385476e-04,
#        2.21475391e-04, 1.08773958e-04, 9.64150749e-05, 8.16311585e-05,
#        1.06357009e-04, 1.32580215e-04, 3.38997721e-04, 1.42892866e-04,
#        1.15094022e-04, 1.35287992e-04, 1.17937168e-04, 1.56101509e-04,
#        1.03870458e-04, 1.67016624e-04, 1.57293427e-04, 3.18745733e-04,
#        8.51158766e-05, 1.38790041e-04, 1.57381495e-04, 1.53021814e-04,
#        1.05249514e-04, 1.19377342e-04, 1.33291047e-04, 1.07844433e-04,
#        9.16264617e-05, 8.34489692e-05, 1.15316179e-04, 1.97819580e-04,
#        1.65892110e-04, 1.34354923e-04, 7.71161722e-05, 9.82002166e-05,
#        1.23657344e-04, 1.10288551e-04, 1.35035734e-04, 1.12827111e-04,
#        1.16494819e-04, 1.18575263e-04, 1.38868563e-04, 1.20552068e-04,
#        2.00896655e-04, 2.23089839e-04, 1.23698628e-04, 1.05779407e-04,
#        9.14641641e-05, 1.36596354e-04, 1.18018179e-04, 1.30147513e-04,
#        1.24546277e-04, 2.45859381e-04, 1.32486559e-04, 1.69926716e-04,
#        9.42235783e-05, 3.09938187e-04, 1.89663158e-04, 1.16117255e-04,
#        1.07170519e-04, 1.74662593e-04, 1.57452960e-04, 1.32879068e-04,
#        3.76606156e-04, 7.41378535e-05, 8.75953265e-05, 1.46198072e-04,
#        9.55126234e-05, 1.58026116e-04, 7.41841141e-05, 1.64735698e-04,
#        1.50838474e-04, 1.78379982e-04, 8.55806356e-05, 6.67955319e-05,
#        1.67537655e-04, 1.37340248e-04, 1.65688616e-04, 1.32085377e-04,
#        1.19559190e-04, 1.76905261e-04, 1.60260446e-04, 1.68695537e-04,
#        2.68959178e-04, 1.26363753e-04, 8.10048659e-05, 1.10472240e-04,
#        1.46377351e-04, 1.32355097e-04, 1.73116525e-04, 9.00652958e-05,
#        1.09670786e-04, 1.62891636e-04, 1.15897194e-04, 1.23086938e-04,
#        1.06848034e-04, 1.29070046e-04, 1.39878597e-04, 1.31084598e-04,
#        1.67585269e-04, 1.46043254e-04, 1.75221823e-04, 1.50357911e-04,
#        1.96480702e-04, 1.32967310e-04, 1.93074433e-04, 1.53213536e-04,
#        1.36801682e-04, 1.20777855e-04, 1.51515647e-04, 1.26372790e-04,
#        2.94659374e-04, 1.15438430e-04, 1.06638538e-04, 1.22262849e-04,
#        1.33667738e-04, 1.60851938e-04, 1.31710782e-04, 2.54046783e-04,
#        1.31380846e-04, 1.34620161e-04, 1.08120839e-04, 9.08110815e-05,
#        1.33446476e-04, 1.08755696e-04, 1.75400230e-04, 1.20275196e-04,
#        1.24028200e-04, 1.26111656e-04, 1.19040720e-04, 1.08592154e-04,
#        9.74857394e-05, 1.27405612e-04, 1.47259736e-04, 1.06108790e-04,
#        1.33177469e-04, 1.67230362e-04, 1.39394266e-04, 1.47954153e-04,
#        9.55184514e-05, 1.38120464e-04, 8.73131794e-05, 1.07129243e-04,
#        2.99184991e-04, 1.07033258e-04, 1.17298703e-04, 1.55454982e-04,
#        1.28301428e-04, 1.21795718e-04, 1.00616635e-04, 1.05303327e-04,
#        1.08045577e-04, 2.02781099e-04, 1.38411750e-04, 1.94075183e-04,
#        1.48675230e-04, 1.54771260e-04, 3.00754968e-04, 1.00005054e-04,
#        1.25465187e-04, 9.90165718e-05, 1.01491212e-04, 1.90835242e-04,
#        1.26988569e-04, 1.22577956e-04, 1.85327561e-04, 1.65267091e-04,
#        2.24034986e-04, 1.70311396e-04, 1.26588100e-04, 2.18561996e-04,
#        1.47908577e-04, 1.79912982e-04, 1.74415574e-04, 1.88331906e-04,
#        1.47189668e-04, 1.11097186e-04, 1.10737630e-04, 1.34081623e-04,
#        1.37447161e-04, 1.47368337e-04, 9.77456584e-05, 1.30803135e-04,
#        1.57209899e-04, 7.87145837e-05, 2.15107852e-04, 1.57658214e-04,
#        1.91630374e-04, 2.92585260e-04, 1.04360071e-04, 1.29182488e-04,
#        2.05478442e-04, 1.63858727e-04, 9.61338446e-05, 1.32262867e-04,
#        2.39153145e-04, 9.70057154e-05, 1.05419480e-04, 1.20503675e-04,
#        2.18039859e-04, 1.21656769e-04, 9.71795162e-05, 1.17982723e-04,
#        1.58224851e-04, 1.50962660e-04, 1.87382931e-04, 1.03601866e-04,
#        1.15855211e-04, 1.55236907e-04, 1.42964971e-04, 1.85133438e-04,
#        1.40885080e-04, 1.94406952e-04, 9.60424877e-05, 2.05839126e-04,
#        1.64673664e-04, 1.13084687e-04, 1.65152553e-04, 1.41796816e-04,
#        1.30005850e-04, 3.58867983e-04, 1.04140745e-04, 1.82006843e-04,
#        2.07221630e-04, 1.59149073e-04, 2.29359837e-04, 4.85541648e-04,
#        1.30418630e-04, 2.90705386e-04, 1.24081780e-04, 1.19931021e-04,
#        1.28667321e-04, 1.84087301e-04, 9.80614277e-05, 2.22758405e-04,
#        1.05426931e-04, 1.77055292e-04, 9.25851273e-05, 1.06512205e-04,
#        1.55285481e-04, 2.02722891e-04, 1.41809403e-04, 1.74173721e-04,
#        1.92475272e-04, 1.02193117e-04, 1.63277975e-04, 8.65282636e-05,
#        1.36504546e-04, 1.28446016e-04, 1.92484818e-04, 1.34946007e-04,
#        8.84604306e-05, 8.45260147e-05, 1.58177339e-04, 1.04612671e-04,
#        1.42520788e-04, 9.56237200e-05, 8.23214796e-05, 1.11470756e-04,
#        1.79725539e-04, 1.65421632e-04, 1.35878130e-04, 1.91996791e-04,
#        1.22820755e-04, 1.61414675e-04, 1.63397926e-04, 1.16753741e-04,
#        1.50416148e-04, 8.44496244e-05, 1.39452357e-04, 1.77817448e-04,
#        2.23899769e-04, 3.89962515e-04, 1.53862944e-04, 1.27767475e-04,
#        1.68030805e-04, 1.87680693e-04, 1.98603084e-04, 1.98747090e-04,
#        1.01305734e-04, 1.26457671e-04, 2.26150049e-04, 1.14659539e-04,
#        1.20377677e-04, 1.38935196e-04, 2.81934685e-04, 1.02886144e-04,
#        6.28497568e-04, 1.25189210e-04, 7.50343752e-05, 1.26277126e-04,
#        9.89774853e-05, 1.33121721e-04, 1.34458882e-04, 8.90121883e-05,
#        1.29758730e-04, 1.64431200e-04, 2.07873600e-04, 1.81996773e-04,
#        1.19830176e-04, 2.31945989e-04, 2.96174811e-04, 1.31972061e-04,
#        1.45958038e-04, 1.43022655e-04, 2.18495901e-04, 8.63115056e-05,
#        1.92272928e-04, 1.20565746e-04, 1.14394446e-04, 1.68719664e-04,
#        2.39536384e-04, 2.22098257e-04, 1.27749925e-04, 1.81741285e-04,
#        8.61947847e-05, 1.62836659e-04, 1.94133681e-04, 1.11636808e-04,
#        1.13319598e-04, 1.53226239e-04, 1.45645608e-04, 1.45585189e-04,
#        8.72255478e-05, 1.26759885e-04, 1.52404449e-04, 1.28265456e-04,
#        1.15974275e-04, 9.95825903e-05, 2.35008425e-04, 1.35321679e-04,
#        1.81362979e-04, 1.16936935e-04, 1.76873888e-04, 1.51734566e-04,
#        1.64567056e-04, 1.03244820e-04, 1.78969043e-04, 2.01437069e-04,
#        1.33845795e-04, 1.02577833e-04, 1.66612866e-04, 1.87422236e-04,
#        1.44495920e-04, 1.46494102e-04, 9.67318992e-05, 1.46732214e-04,
#        1.11708287e-04, 1.09432163e-04, 1.03838574e-04, 1.28650136e-04,
#        4.78235364e-04, 1.05051862e-04, 1.85887984e-04, 1.49029845e-04,
#        8.08327095e-05, 1.30523636e-04, 1.56111331e-04, 1.44192119e-04,
#        1.69636565e-04, 1.06074287e-04, 7.45866855e-05, 1.67280610e-04,
#        1.11424517e-04, 1.09553293e-04, 7.70083570e-05, 7.37546507e-05,
#        1.08575689e-04, 2.22522300e-04, 1.32890622e-04, 1.41445271e-04,
#        2.08634840e-04, 1.36205985e-04, 1.61561446e-04, 1.97221860e-04,
#        1.11569650e-04, 1.23319580e-04, 1.13980313e-04, 1.28276093e-04,
#        2.03102391e-04, 1.19131117e-04, 1.41293713e-04, 1.41564553e-04,
#        1.35832655e-04, 1.21675330e-04, 1.26932748e-04, 1.11033514e-04,
#        1.12942631e-04, 1.21512181e-04, 2.44110153e-04, 7.56893278e-05,
#        1.63938763e-04, 7.18332958e-05, 1.91549072e-04, 1.32127592e-04,
#        1.05688057e-04, 1.15394840e-04, 2.06543700e-04, 1.37636453e-04,
#        7.70256229e-05, 1.69164676e-04, 1.41905984e-04, 1.55121030e-04,
#        1.30527857e-04, 8.50996366e-05, 1.58601033e-04, 9.92968562e-05,
#        1.53525820e-04, 1.38930554e-04, 1.33779700e-04, 2.26355260e-04,
#        2.49703007e-04, 1.68783561e-04, 2.78709456e-04, 1.32402434e-04,
#        2.14755084e-04, 1.98966896e-04, 1.10797206e-04, 1.29868291e-04,
#        3.61174170e-04, 1.26450555e-04, 1.75583642e-04, 1.40506687e-04,
#        1.08214190e-04, 1.17749827e-04, 1.65044228e-04, 7.92941355e-05,
#        1.71186650e-04, 1.42664532e-04, 1.48690116e-04, 1.73127744e-04,
#        1.54491208e-04, 1.42202276e-04, 1.34796152e-04, 1.30053581e-04],
#       dtype=float32)

# %%
np.argmax(yh[6])
# Out:
# 8
